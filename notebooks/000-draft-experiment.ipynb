# %%
import os
os.environ['OPENBLAS_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
os.environ['BLIS_NUM_THREADS'] = '1'
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['TF_NUM_INTEROP_THREADS'] = '1'
os.environ['TF_NUM_INTRAOP_THREADS'] = '1'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import logging
import json

import pandas as pd

import smote_variants
from smote_variants import get_simplex_sampling_oversamplers
from smote_variants.evaluation import evaluate_oversamplers

import common_datasets
from common_datasets.binary_classification import get_filtered_data_loaders, get_data_loaders

logger = logging.getLogger('smote_variants')
logger.setLevel(logging.CRITICAL)

smote_variants.config.suppress_external_warnings(False)
smote_variants.config.suppress_internal_warnings(False)
# Out:
# False

# %%
oversamplers = get_simplex_sampling_oversamplers(within_simplex_sampling='random', 
                                                    n_dim_range=2, 
                                                    n_quickest=50)

# %%
oversamplers
# Out:
# [smote_variants.oversampling._smote.SMOTE,
#  smote_variants.oversampling._g_smote.G_SMOTE,
#  smote_variants.oversampling._gaussian_smote.Gaussian_SMOTE,
#  smote_variants.oversampling._borderline_smote.Borderline_SMOTE1,
#  smote_variants.oversampling._cure_smote.CURE_SMOTE,
#  smote_variants.oversampling._borderline_smote.Borderline_SMOTE2,
#  smote_variants.oversampling._edge_det_smote.Edge_Det_SMOTE,
#  smote_variants.oversampling._sl_graph_smote.SL_graph_SMOTE,
#  smote_variants.oversampling._smmo.SMMO,
#  smote_variants.oversampling._distance_smote.distance_SMOTE,
#  smote_variants.oversampling._cbso.CBSO,
#  smote_variants.oversampling._lee.Lee,
#  smote_variants.oversampling._smote_tomeklinks.SMOTE_TomekLinks,
#  smote_variants.oversampling._smote_rsb.SMOTE_RSB,
#  smote_variants.oversampling._assembled_smote.Assembled_SMOTE,
#  smote_variants.oversampling._ndo_sampling.NDO_sampling,
#  smote_variants.oversampling._oups.OUPS,
#  smote_variants.oversampling._nras.NRAS,
#  smote_variants.oversampling._ismote.ISMOTE,
#  smote_variants.oversampling._ans.ANS,
#  smote_variants.oversampling._sn_smote.SN_SMOTE,
#  smote_variants.oversampling._and_smote.AND_SMOTE,
#  smote_variants.oversampling._trim_smote.TRIM_SMOTE,
#  smote_variants.oversampling._cluster_smote.cluster_SMOTE,
#  smote_variants.oversampling._smote_enn.SMOTE_ENN,
#  smote_variants.oversampling._somo.SOMO,
#  smote_variants.oversampling._smote_frst_2t.SMOTE_FRST_2T,
#  smote_variants.oversampling._asmobd.ASMOBD,
#  smote_variants.oversampling._vis_rst.VIS_RST,
#  smote_variants.oversampling._adasyn.ADASYN,
#  smote_variants.oversampling._smote_ipf.SMOTE_IPF,
#  smote_variants.oversampling._mwmote.MWMOTE,
#  smote_variants.oversampling._kmeans_smote.kmeans_SMOTE,
#  smote_variants.oversampling._prowsyn.ProWSyn,
#  smote_variants.oversampling._msyn.MSYN,
#  smote_variants.oversampling._neater.NEATER,
#  smote_variants.oversampling._lle_smote.LLE_SMOTE,
#  smote_variants.oversampling._svm_balance.SVM_balance,
#  smote_variants.oversampling._nrsboundary_smote.NRSBoundary_SMOTE,
#  smote_variants.oversampling._sdsmote.SDSMOTE,
#  smote_variants.oversampling._supervised_smote.Supervised_SMOTE,
#  smote_variants.oversampling._isomap_hybrid.ISOMAP_Hybrid,
#  smote_variants.oversampling._ce_smote.CE_SMOTE,
#  smote_variants.oversampling._e_smote.E_SMOTE,
#  smote_variants.oversampling._mot2ld.MOT2LD]

# %%
datasets = get_filtered_data_loaders(n_col_bounds=(2, 150), 
                                        n_minority_bounds=(10, 10000), 
                                        n_bounds=(50, 2500),
                                        n_smallest=50, 
                                        sorting='n',
                                        n_from_phenotypes=3)

datasets = [dataset() for dataset in datasets]

# %%
classifiers = [('sklearn.neighbors', 'KNeighborsClassifier', {'algorithm': 'brute', 'n_jobs': 1}),
                ('sklearn.tree', 'DecisionTreeClassifier', {'random_state': 5}),
                ('sklearn.ensemble', 'RandomForestClassifier', {'random_state': 5}),
                ('sklearn.svm', 'SVC', {'random_state': 5, 'probability': True}),
                ('smote_variants.classifiers', 'MLPClassifierWrapper', {'random_state': 5})]

# %%
validator_params = {'n_repeats': 2, 'n_splits': 5, 'random_state': 5}

ss_params = {'within_simplex_sampling': 'deterministic',
             'simplex_sampling': 'deterministic'}

vanilla_params = {'random_state': 5, 
                    'n_jobs': 1}

deterministic_params = {'random_state': 5,
                        'ss_params': ss_params,
                        'n_jobs': 1}

# %%
cache_path = os.path.expanduser('~/smote-deterministic')

# %%
# creating oversampler specifications

oversampler_list = [('smote_variants', o.__name__, vanilla_params) for o in oversamplers]
oversampler_deterministic = [('smote_variants', o.__name__, deterministic_params) for o in oversamplers]

all_oversamplers = oversampler_list + oversampler_deterministic

# %%
print(len(all_oversamplers))
print(len(datasets))
# Out:
# 90
# 50

# %%
dataset_names = [dataset['name'] for dataset in datasets]

for dataset_name in sorted(dataset_names):
    print(dataset_name)
# Out:
# CM1
# PC1
# SPECTF
# abalone-19_vs_10-11-12-13
# abalone9_18
# appendicitis
# australian
# bupa
# car-vgood
# car_good
# cleveland-0_vs_4
# crx
# dermatology-6
# ecoli1
# ecoli2
# ecoli3
# flare-F
# glass0
# glass1
# glass2
# haberman
# hepatitis
# ionosphere
# iris0
# kddcup-guess_passwd_vs_satan
# kddcup-land_vs_portsweep
# kr-vs-k-zero_vs_eight
# led7digit-0-2-4-6-7-8-9_vs_1
# mammographic
# monk-2
# new_thyroid1
# page-blocks-1-3_vs_4
# pima
# poker-8-9_vs_6
# poker-8_vs_6
# saheart
# shuttle-6_vs_2-3
# shuttle-c0-vs-c4
# vehicle0
# vehicle1
# vehicle2
# vowel0
# wdbc
# winequality-red-3_vs_5
# winequality-red-4
# winequality-red-8_vs_6
# wisconsin
# yeast1
# yeast3
# yeast4

# %%
results = evaluate_oversamplers(datasets=datasets, 
                                oversamplers=all_oversamplers, 
                                classifiers=classifiers,
                                scaler=('sklearn.preprocessing', 'StandardScaler', {}),
                                validator_params=validator_params,
                                cache_path=cache_path,
                                parse_results=False,
                                clean_up=None,
                                timeout=90,
                                n_jobs=4)
# Out:
# 2022-08-28 10:26:51.794956: processing dataset: appendicitis
# starting  23437 Borderline_SMOTE2starting3
#  23443 SN_SMOTE 2starting
#  23463 E_SMOTE 1starting
#  23481 Borderline_SMOTE1 1
# starting 23511 ISMOTE 1
# starting 23533 SMOTE_ENN 3starting
#  23542 OUPS 3starting
#  23558 NEATER 3
# starting 23590 SMMOstarting  235962
# ADASYN 0
# starting23628  SMMO 3
# starting 23641 NRSBoundary_SMOTEstarting  236552
# MWMOTE 4
# starting 23684 kmeans_SMOTE 4
# starting23705  G_SMOTE 2
# starting 23725starting 23732  SL_graph_SMOTEBorderline_SMOTE2  13starting
#  23746
# CBSO 2
# starting 23783 SOMO 3starting
#  23791 Lee starting0
# 23806 SMOTE_FRST_2Tstarting  223826
#  ANS 4
# starting 123858 CURE_SMOTE starting
#  23868 startingLee  238861
# ASMOBD starting4
# 23897 SL_graph_SMOTE 0
# starting 23927 SMMO 2
# starting 23954 SMOTE
# starting2 23969 MWMOTE 3
# starting23984  SMOTE_ENN 0
# starting 24005 startingMOT2LD  240171
# SMOTE_TomekLinks 2
# starting 24049MOT2LD  4
# starting 24068 ADASYN 4
# starting 24088 NEATER 4
# starting 24098 distance_SMOTE 2
# starting 24126 ANS 1starting
# 24138 NEATER 1
# starting 24164MOT2LD  0
# starting 24174 SOMO 3
# starting 24201 Borderline_SMOTE2 0
# starting 24220 SMOTE_FRST_2T 2
# starting 24239 SMOTE_RSB
# 0starting 24258 SMMO 4
# starting24278  NRAS starting3
#  24284 SOMO 4
# starting 24311 ISMOTE 2
# starting 24335 E_SMOTE 4
# starting 24356 OUPS 2
# starting 24375 AND_SMOTE 4
# starting 24394 ASMOBD 2
# starting 24410 NEATER 4
# starting 24434 TRIM_SMOTE 0
# starting 24454 startingMOT2LD  244610
# LLE_SMOTE 3
# starting 24492 distance_SMOTE 4
# starting 24511SVM_balance  0
# starting 24526 NEATER 0
# starting 24549 SOMO 4
# starting 24568 SMOTE_RSB 1
# starting 24587 VIS_RST 2
# starting 24600  SMOTE_ENN2
# starting 24626 ADASYN 2
# starting24638  ANS 4
# starting 24659 Lee 4
# startingstarting  2468924683  SMOTE_TomekLinksstartingdistance_SMOTE   4324697
#
#  SMMO 0
# starting 24733 NRSBoundary_SMOTE 1
# starting 24759 cluster_SMOTEstarting  224764
#  Lee 4starting
#  24784 distance_SMOTE 2
# starting 24818 SMOTE starting0
# 24824 Borderline_SMOTE1 starting4
# 24845 TRIM_SMOTE 0
# starting 24872 SMOTE_TomekLinks 1
# starting 24889 ADASYN starting0
# 24906 MOT2LD 1
# starting 24935 NEATER 0
# starting 24955starting  VIS_RST24959  2NDO_sampling
# 4
# starting 24993 MSYN 2
# starting 25010 Assembled_SMOTE 4starting
# 25027 SMOTE_TomekLinks 0
# starting 25052 startingSDSMOTE 25061 2
# ANS 2
# starting 25090 SMOTE_ENN 2
# starting 25111  distance_SMOTE2starting
#  25121 AND_SMOTE 1starting
#  25139  CE_SMOTE2
# starting 25166 SMMO 3starting
# 25183 ISOMAP_Hybrid 3starting
#  25197 cluster_SMOTE 2
# starting 25224 SMOTE 0
# starting25245  ASMOBD 2starting
#  25251 MWMOTE 1
# starting 25282 AND_SMOTE 1
# starting 25304 ISMOTE starting2
# 25310 SMOTE_TomekLinks 0
# starting 25342 CURE_SMOTE
# 2starting starting25362 G_SMOTE 2
#  25367 SMOTE_IPF 4starting
#  25392 SMOTE 3
# starting 25411 Borderline_SMOTE2 2
# starting 25429 SMOTE_TomekLinks 3
# starting 25456 CURE_SMOTE
# 0starting 25477 SMOTE 4starting
#  25484 Edge_Det_SMOTE 1
# starting starting25508  25517CBSO  SMOTE_RSB1
# 1
# starting 25536 startingcluster_SMOTE  325560
#  ProWSyn 4
# starting 25595starting  ISMOTE25604  1
# SVM_balance 1
# starting 25635 startingMWMOTE 25642  0SMOTE_TomekLinks
# 1
# starting 25668 SVM_balance 2
# starting 25693 CE_SMOTE starting3
# 25701 SMOTE_IPF 2
# starting 25732 startingSupervised_SMOTE  1
# 25736 E_SMOTE 2
# starting 25769 SMOTE_RSB 1
# starting 25788 Assembled_SMOTE 1
# starting 25808 Edge_Det_SMOTE 1
# starting25828   SDSMOTEstarting1
# 25835 CURE_SMOTE starting2
#  25855 cluster_SMOTE 3
# starting 25886 SN_SMOTE 3
# starting 25905 Borderline_SMOTE2 3
# starting 25926SMOTE_FRST_2T  3
# starting 25937 VIS_RST 4starting
#  25955 AND_SMOTE 0
# starting 25984 MSYNstarting  225990
#  AND_SMOTE 3
# starting26023  SVM_balance 3starting
# 26039starting   26051LLE_SMOTE Assembled_SMOTE 0
# 2starting
#  26073 SN_SMOTE 2
# starting 26100 E_SMOTE 0
# starting 26121 Gaussian_SMOTE 1
# starting 26129 startingSMOTE_ENN  261451
# E_SMOTE 1
# starting 26176 NEATER
#  4starting 26195 Lee 4
# starting 26214 MWMOTE 2
# starting 26233 ANS 3
# starting 26253 E_SMOTE 2
# starting 26272 SMOTE_IPF 3
# starting 26291 SMOTE_RSB 1
# starting 26310 kmeans_SMOTE 1
# starting 26330 AND_SMOTE 3
# starting 26349 ASMOBD 1
# starting 26369 MOT2LD 3
# starting 26375 NRAS 4
# starting 26408 SMOTEstarting  126414
#  MSYN 4
# starting 26446 Borderline_SMOTE1 starting0
#  26457 Supervised_SMOTE 0
# starting 26485 SMOTE_RSB 3
# starting 26505 NDO_sampling 3starting
#  26511 SL_graph_SMOTE 4
# starting26542  SMOTE_FRST_2T 3
# starting26562  distance_SMOTE starting1
#  26568 ISMOTE 4
# starting 26602 ADASYN 3starting
#  26608 ProWSyn 3starting
#  26626 G_SMOTE 1
# starting26659  SDSMOTE 4starting
#  26666 G_SMOTE starting2
#  26687 SVM_balance 0
# starting 26710 CURE_SMOTE 4
# starting 26735 SMOTE_IPF 2
# starting 26755 starting 26761Lee SVM_balance 3
#  2
# starting 26792 SN_SMOTE 2
# starting 26810 startingNRSBoundary_SMOTE  268211
#  G_SMOTE 4
# starting  26852 LLE_SMOTE1starting
#  26858 ISOMAP_Hybridstarting  126878
#  AND_SMOTE 3
# starting 26907 Assembled_SMOTE 0
# starting 26929 SMOTE_ENN 4starting
#  26937 CE_SMOTE 4starting
#  26959 TRIM_SMOTE 2
# starting starting 2698326992 ASMOBD ISOMAP_Hybrid  03
#
# starting 27023 kmeans_SMOTE 2
# starting 27044 CBSO 0
# starting 27063 SOMO 0
# starting 27083 startingdistance_SMOTE  270913
# kmeans_SMOTE 2
# starting 27118 Lee 3
# starting 27140 VIS_RST 0
# starting  27159NDO_sampling 2
# starting 27175 startingCURE_SMOTE  1
# 27186 ANS 1
# starting starting 2720727223  Borderline_SMOTE1NRSBoundary_SMOTE 4
# 1
# starting 27248 AND_SMOTE 0
# starting 27274 Edge_Det_SMOTE 3
# starting 27296 CBSO 3
# starting 27304 G_SMOTE 0
# starting 27322 Supervised_SMOTE 2
# starting 27347 AND_SMOTE 4
# starting 27364 TRIM_SMOTE 1starting
#  27378 SN_SMOTE 0
# starting 27408  SMMO4
# starting 27427 SMMO 1
# startingstarting 27447 SMOTE_IPF 4
# 27453 MWMOTE 3
# starting 27475 starting SL_graph_SMOTE27489  3cluster_SMOTE
#  0
# starting 27525 startingSMMO  127533
# Edge_Det_SMOTE 0
# starting 27564 SMOTE 4
# starting 27575 SVM_balance 3
# starting 27589starting ISMOTE
#  276074 kmeans_SMOTE 0
# starting 27634 ProWSyn 0
# starting27661
# CURE_SMOTE 3starting starting27674  27684ANS Edge_Det_SMOTE  14
#
# starting 27718 starting 27723 SL_graph_SMOTETRIM_SMOTE 0 0
# starting
#  27740starting  AND_SMOTE27762 2
# Borderline_SMOTE2 0
# starting 27794 TRIM_SMOTE 2
# starting 27815 NEATER 0starting
#  27821 SMOTE_RSB starting0
# 27839 G_SMOTE 4
# starting 27866 SOMO 3
# starting 27891
#  SOMO 3starting 27901 SN_SMOTE 3starting
#  27916 SL_graph_SMOTE 2
# starting 27943  Edge_Det_SMOTE4
# starting 27966 Edge_Det_SMOTE 3
# starting 27982 starting 27990ProWSyn  SMOTE_FRST_2T2
#  4
# starting SMOTE_TomekLinks28022 starting 4
# 28033 kmeans_SMOTE 1
# starting 28065
#  MOT2LDstarting  3
# 28075 NDO_sampling 1starting 28101 SMOTE_ENN 0
# startingNEATER 28120  4starting 28140
#  G_SMOTE 3starting
#  28152 CE_SMOTE 0
# starting 28179 startingAssembled_SMOTE 0 28183
#  CE_SMOTE 1
# starting 28218 Gaussian_SMOTE 1
# starting 28237 CE_SMOTE 3
# starting 28257 LLE_SMOTE 0
# starting 28276 Gaussian_SMOTE 0
# starting 28296 SMOTE_FRST_2Tstarting  328303
#  SMOTE_ENN starting4
# 28321 cluster_SMOTE 3
# starting 28354 startingOUPS  283624
#   ISMOTE1
# starting 28391 Borderline_SMOTE10
# starting 28412 startingSupervised_SMOTE  284194
# SDSMOTE 0
# starting 28450 Supervised_SMOTE 3
# starting 28470 ANS 1
# starting 28489 cluster_SMOTE 1
# starting 28508 SVM_balance 2
# starting 28528 Edge_Det_SMOTE 0
# starting 28549 cluster_SMOTE 4starting
#  28555 Edge_Det_SMOTE 1
# starting 28578 NRSBoundary_SMOTE 2
# starting 28599 ANS 0
# starting 28624 G_SMOTE 1
# starting 28644 ANS
#  2starting 28659 NDO_sampling 3
# starting 28676 Gaussian_SMOTE starting4 28688 NRAS 1
#
# starting 28713 ISMOTE 0
# starting 28739SMOTE_IPF   2starting
# 28751 ISOMAP_Hybrid starting1 28769
#  TRIM_SMOTE 1
# starting 28796 ProWSyn 4
# starting 28817 NDO_sampling 0starting
#  28826 MWMOTEstarting  028845
#  Assembled_SMOTE 0
# starting 28870 ProWSyn starting3
#  28882 E_SMOTE 2
# starting 28915 AND_SMOTE starting3 28924
#  Gaussian_SMOTE 3
# starting 28944 ProWSyn 1
# starting 28973 SMOTE_FRST_2T starting3
#  28985 Lee 2
# starting 29011
#  NRAS 0starting starting29024  29034SOMO  ASMOBD2
# 0
# starting 29067 SOMO 1
# starting 29087 cluster_SMOTE 0
# starting 29108starting  SL_graph_SMOTE29112 0
#  SOMO 4
# starting29146  ASMOBDstarting  429151
# distance_SMOTE 0
# starting 29175 CURE_SMOTE 1
# starting 29203 Gaussian_SMOTE3
# starting 29223 startingSMOTE_IPF  292290
# Edge_Det_SMOTE 2
# starting 29253 SMOTE starting 292671 SOMO
#  0
# starting 29305 NDO_sampling 3starting
#  29320 3Assembled_SMOTE
# starting 29343 startingVIS_RST  293503
#  kmeans_SMOTEstarting  329367
#  SMOTE_TomekLinks 2
# starting3 29403 ANS starting
#  29409 VIS_RST 1
# starting 29429 G_SMOTE 1
# starting0 29459 CURE_SMOTE starting
# 29467 Supervised_SMOTE 1
# starting 29491 SMOTE_RSB 4
# starting 29508 NRSBoundary_SMOTE 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> results = evaluate_oversamplers(datasets=datasets,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>                                 oversamplers=all_oversamplers,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>                                 classifiers=classifiers,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>                                 scaler=('sklearn.preprocessing', 'StandardScaler', {}),
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>                                 validator_params=validator_params,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>                                 cache_path=cache_path,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>                                 parse_results=False,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>                                 clean_up=None,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>                                 timeout=90,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/research_deterministic_oversampling/notebooks/000-draft-experiment.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>                                 n_jobs=4)
#
# File ~/workspaces/smote_variants/smote_variants/evaluation/_functions.py:508, in evaluate_oversamplers(datasets, oversamplers, classifiers, cache_path, validator_params, scaler, serialization, clean_up, n_jobs, timeout, parse_results, explicit_gc, verbosity)
#     505 for dataset in datasets:
#     506     _verbose_logging(f"processing dataset: {dataset['name']}", verbosity)
# --> 508     all_results.extend(evaluate_oversampler_on_dataset(dataset=dataset,
#     509                                                         oversamplers=oversamplers,
#     510                                                         classifiers=classifiers,
#     511                                                         cache_path=cache_path,
#     512                                                         validator_params=validator_params,
#     513                                                         scaler=scaler,
#     514                                                         serialization=serialization,
#     515                                                         clean_up=clean_up,
#     516                                                         n_jobs=n_jobs,
#     517                                                         timeout=timeout,
#     518                                                         explicit_gc=explicit_gc))
#     520 all_results = _unify_lists(all_results)
#     521 return do_parse_results(all_results, parse_results, serialization)
#
# File ~/workspaces/smote_variants/smote_variants/evaluation/_functions.py:419, in evaluate_oversampler_on_dataset(dataset, oversamplers, classifiers, cache_path, validator_params, scaler, serialization, clean_up, n_jobs, timeout, explicit_gc)
#     410     all_results.extend(Parallel(n_jobs=n_jobs,
#     411                                 batch_size=1)(delayed(execute_1_job)(fold,
#     412                                                                 oversamplers,
#    (...)
#     415                                                                 serialization)
#     416                                                 for fold in folding.fold()))
#     418 else:
# --> 419     all_results.extend(cached_evaluation(folding=folding,
#     420                                         oversamplers=oversamplers,
#     421                                         classifiers=classifiers,
#     422                                         scaler=scaler,
#     423                                         cache_path=cache_path,
#     424                                         serialization=serialization,
#     425                                         n_jobs=n_jobs,
#     426                                         timeout=timeout,
#     427                                         clean_up=clean_up))
#     429 # optionally explicitly execute garbage collection after each dataset
#     430 if explicit_gc:
#
# File ~/workspaces/smote_variants/smote_variants/evaluation/_functions.py:320, in cached_evaluation(folding, oversamplers, classifiers, scaler, cache_path, serialization, n_jobs, timeout, clean_up)
#     317 cache_path_tmp = os.path.join(cache_path, folding.properties['name'])
#     319 if n_jobs > 1:
# --> 320     results_os = execute_parallel_oversampling(folding=folding,
#     321                                                 oversamplers=oversamplers,
#     322                                                 scaler=scaler,
#     323                                                 cache_path_tmp=cache_path_tmp,
#     324                                                 serialization=serialization,
#     325                                                 n_jobs=n_jobs,
#     326                                                 timeout=timeout)
#     327 else:
#     328     results_os = []
#
# File ~/workspaces/smote_variants/smote_variants/evaluation/_functions.py:285, in execute_parallel_oversampling(folding, oversamplers, scaler, cache_path_tmp, serialization, n_jobs, timeout)
#     281 np.random.shuffle(jobs)
#     283 ttpp = ThreadTimeoutProcessPool(n_jobs, timeout)
# --> 285 results_os = ttpp.execute(jobs=jobs)
#     287 return results_os
#
# File ~/workspaces/smote_variants/smote_variants/evaluation/_parallelization.py:242, in ThreadTimeoutProcessPool.execute(self, jobs)
#     239     thread.start()
#     241 for thread in pool:
# --> 242     thread.join()
#     244 return self.results
#
# File ~/anaconda3/envs/deterministic/lib/python3.10/threading.py:1089, in Thread.join(self, timeout)
#    1086     raise RuntimeError("cannot join current thread")
#    1088 if timeout is None:
# -> 1089     self._wait_for_tstate_lock()
#    1090 else:
#    1091     # the behavior of a negative timeout isn't documented, but
#    1092     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1093     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/deterministic/lib/python3.10/threading.py:1105, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1103 if lock is None:  # already determined that the C code is done
#    1104     assert self._is_stopped
# -> 1105 elif lock.acquire(block, timeout):
#    1106     lock.release()
#    1107     self._stop()
#
# KeyboardInterrupt:
# starting 29537 NDO_sampling 4
# starting 29556 SMMO 2
# starting 29575 SVM_balance 3
# starting 29594 CBSO 1
# starting

# %%
datasets = smote_variants.evaluation.datasets_in_cache(cache_path)

# %%
datasets
# Out:
# {'car_good': '/home/gykovacs/smote-deterministic/car_good',
#  'shuttle-c0-vs-c4': '/home/gykovacs/smote-deterministic/shuttle-c0-vs-c4',
#  'cleveland-0_vs_4': '/home/gykovacs/smote-deterministic/cleveland-0_vs_4',
#  'haberman': '/home/gykovacs/smote-deterministic/haberman',
#  'abalone9_18': '/home/gykovacs/smote-deterministic/abalone9_18',
#  'wisconsin': '/home/gykovacs/smote-deterministic/wisconsin',
#  'vehicle0': '/home/gykovacs/smote-deterministic/vehicle0',
#  'abalone-19_vs_10-11-12-13': '/home/gykovacs/smote-deterministic/abalone-19_vs_10-11-12-13',
#  'poker-8_vs_6': '/home/gykovacs/smote-deterministic/poker-8_vs_6',
#  'hepatitis': '/home/gykovacs/smote-deterministic/hepatitis',
#  'flare-F': '/home/gykovacs/smote-deterministic/flare-F',
#  'shuttle-6_vs_2-3': '/home/gykovacs/smote-deterministic/shuttle-6_vs_2-3',
#  'pima': '/home/gykovacs/smote-deterministic/pima',
#  'mammographic': '/home/gykovacs/smote-deterministic/mammographic',
#  'dermatology-6': '/home/gykovacs/smote-deterministic/dermatology-6',
#  'kddcup-land_vs_portsweep': '/home/gykovacs/smote-deterministic/kddcup-land_vs_portsweep',
#  'winequality-red-8_vs_6': '/home/gykovacs/smote-deterministic/winequality-red-8_vs_6',
#  'ecoli2': '/home/gykovacs/smote-deterministic/ecoli2',
#  'winequality-red-3_vs_5': '/home/gykovacs/smote-deterministic/winequality-red-3_vs_5',
#  'poker-8-9_vs_6': '/home/gykovacs/smote-deterministic/poker-8-9_vs_6',
#  'wdbc': '/home/gykovacs/smote-deterministic/wdbc',
#  'vehicle1': '/home/gykovacs/smote-deterministic/vehicle1',
#  'vehicle2': '/home/gykovacs/smote-deterministic/vehicle2',
#  'car-vgood': '/home/gykovacs/smote-deterministic/car-vgood',
#  'kr-vs-k-zero_vs_eight': '/home/gykovacs/smote-deterministic/kr-vs-k-zero_vs_eight',
#  'crx': '/home/gykovacs/smote-deterministic/crx',
#  'yeast3': '/home/gykovacs/smote-deterministic/yeast3',
#  'appendicitis': '/home/gykovacs/smote-deterministic/appendicitis',
#  'vowel0': '/home/gykovacs/smote-deterministic/vowel0',
#  'glass1': '/home/gykovacs/smote-deterministic/glass1',
#  'saheart': '/home/gykovacs/smote-deterministic/saheart',
#  'bupa': '/home/gykovacs/smote-deterministic/bupa',
#  'winequality-red-4': '/home/gykovacs/smote-deterministic/winequality-red-4',
#  'ecoli3': '/home/gykovacs/smote-deterministic/ecoli3',
#  'monk-2': '/home/gykovacs/smote-deterministic/monk-2',
#  'glass2': '/home/gykovacs/smote-deterministic/glass2',
#  'page-blocks-1-3_vs_4': '/home/gykovacs/smote-deterministic/page-blocks-1-3_vs_4',
#  'ionosphere': '/home/gykovacs/smote-deterministic/ionosphere',
#  'kddcup-guess_passwd_vs_satan': '/home/gykovacs/smote-deterministic/kddcup-guess_passwd_vs_satan',
#  'led7digit-0-2-4-6-7-8-9_vs_1': '/home/gykovacs/smote-deterministic/led7digit-0-2-4-6-7-8-9_vs_1',
#  'yeast1': '/home/gykovacs/smote-deterministic/yeast1',
#  'PC1': '/home/gykovacs/smote-deterministic/PC1',
#  'glass0': '/home/gykovacs/smote-deterministic/glass0',
#  'new_thyroid1': '/home/gykovacs/smote-deterministic/new_thyroid1',
#  'australian': '/home/gykovacs/smote-deterministic/australian',
#  'iris0': '/home/gykovacs/smote-deterministic/iris0',
#  'CM1': '/home/gykovacs/smote-deterministic/CM1',
#  'ecoli1': '/home/gykovacs/smote-deterministic/ecoli1',
#  'SPECTF': '/home/gykovacs/smote-deterministic/SPECTF',
#  'yeast4': '/home/gykovacs/smote-deterministic/yeast4'}

# %%
all_data = []
for dataset in datasets:
    print(dataset)
    data = smote_variants.evaluation.load_dataset_data(datasets[dataset])
    summary = smote_variants.evaluation.create_summary(data)
    summary.to_csv(os.path.join(datasets[dataset], f'summary_{dataset}.csv'))
    data['dataset'] = data['fold_descriptor'].apply(lambda x: x['name'])
    all_data.append(data[['oversampling_error', 'dataset', 'oversampler', 'oversampling_warning']])
# Out:
# car_good
# shuttle-c0-vs-c4
# cleveland-0_vs_4
# haberman
# abalone9_18
# wisconsin
# vehicle0
# abalone-19_vs_10-11-12-13
# poker-8_vs_6
# hepatitis
# flare-F
# shuttle-6_vs_2-3
# pima
# mammographic
# dermatology-6
# kddcup-land_vs_portsweep
# winequality-red-8_vs_6
# ecoli2
# winequality-red-3_vs_5
# poker-8-9_vs_6
# wdbc
# vehicle1
# vehicle2
# car-vgood
# kr-vs-k-zero_vs_eight
# crx
# yeast3
# appendicitis
# vowel0
# glass1
# saheart
# bupa
# winequality-red-4
# ecoli3
# monk-2
# glass2
# page-blocks-1-3_vs_4
# ionosphere
# kddcup-guess_passwd_vs_satan
# led7digit-0-2-4-6-7-8-9_vs_1
# yeast1
# PC1
# glass0
# new_thyroid1
# australian
# iris0
# CM1
# ecoli1
# SPECTF
# yeast4

# %%
pdf = pd.concat(all_data).reset_index(drop=True)

# %%
pdf.head()
# Out:
#   oversampling_error   dataset   oversampler  \
# 0               None  car_good           ANS
# 1               None  car_good           ANS
# 2               None  car_good        MOT2LD
# 3               None  car_good  kmeans_SMOTE
# 4               None  car_good     SMOTE_RSB
#
#                                 oversampling_warning
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [("<class 'UserWarning'>", UserWarning('kmeans...
# 4                                                 []

# %%
pdf = pdf.reset_index(drop=True)

# %%
len(pdf)
# Out:
# 100000

# %%
pdf[~pdf['oversampling_error'].isnull()][['oversampling_error', 'dataset', 'oversampler', 'oversampling_warning']].drop_duplicates().values
# Out:
# array([], shape=(0, 4), dtype=object)

# %%
pdf[~pdf['oversampling_error'].isnull()][['oversampling_error', 'dataset', 'oversampler', 'oversampling_warning']].drop_duplicates().values
# Out:
# array([['TimeOutError', 'car_good', 'NEATER', None],
#        ['TimeOutError', 'car_good', 'MSYN', None],
#        ['TimeOutError', 'poker-8_vs_6', 'AMSCO', None],
#        ['TimeOutError', 'mammographic', 'SOMO', None],
#        ['TimeOutError', 'mammographic', 'ANS', None],
#        ['TimeOutError', 'kddcup-land_vs_portsweep', 'MSYN', None],
#        ['TimeOutError', 'kddcup-land_vs_portsweep', 'NRSBoundary_SMOTE',
#         None],
#        ['TimeOutError', 'poker-8-9_vs_6', 'AMSCO', None],
#        ['TimeOutError', 'winequality-red-4', 'AMSCO', None],
#        ['TimeOutError', 'yeast1', 'Supervised_SMOTE', None],
#        ['TimeOutError', 'PC1', 'AMSCO', None]], dtype=object)
